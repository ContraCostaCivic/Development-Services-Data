# %% [markdown]
# ### datasets
# https://drive.google.com/drive/folders/1Jko1fztHcWCSV2ScGJGOOrJBtJiND7k_
#
# ### contra vista development services github
# https://github.com/ContraCostaCivic/Development-Services-Data
#
# ### design brainstorm
# https://docs.google.com/document/d/1doFyS1y4e9EF85EZr4dNis5MVcjtAOiL1btxfjumMWA/edit?ts=5c7acdd9

# %% [markdown]
# ### Emails
#
# acdeboer@ucdavis.edu
#
# arjun.gupta@berkeley.edu
#
# mjnur@ucdavis.edu
#
# ryankl_2016@berkeley.edu

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

import sqlite3 as sql

# %%
counterData = pd.read_excel("./Shared as of 030119 Front Counter tally (1).xls", sheet_name = 'Daily intake & visitor count')

# %%
counterData
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total deposit</th>
#       <th># receipts</th>
#       <th>Number of Visitors</th>
#       <th>Inspection Stops</th>
#       <th>Inspection Requests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>21500.5</td>
#       <td>27.0</td>
#       <td>16</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11193.7</td>
#       <td>24.0</td>
#       <td>16</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15275.3</td>
#       <td>13.0</td>
#       <td>21</td>
#       <td>NaN</td>
# ...

# %%
counterData = counterData[["total deposit", "# receipts", "Number of Visitors", "Inspection Stops", "Inspection Requests"]]
